# %% [markdown]
# # Analysis

# %% [markdown]
# ## This notebook is

# %% [markdown]
# ### Import sqlite3, Pandas, and the ipython-sql (%sql) Jupyter extension

# %%
import sqlite3
import pandas as pd
import numpy as np

# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ### Connecting to the database

# %%
# %sql sqlite:///airpassenger.db
# Out:
# 'Connected: None@airpassenger.db'

# %%
airportterminal_rs = %sql None@airpassenger.db SELECT * FROM AIRPORTDIMENSION;
airportterminal = airportterminal_rs.DataFrame().set_index('AirportID')
airportterminal
# Out:
# Done.
#                 Terminal BoardingArea
# AirportID
# 1             Terminal 1            B
# 2          International            G
# 3          International            A
# 4             Terminal 3            E
# 5             Terminal 1            C
# 6             Terminal 1            A
# 7             Terminal 3            F
# 8                  Other        Other
# 9             Terminal 2            D

# %%
passenger_rs = %sql None@airpassenger.db SELECT * FROM PASSENGERFACT;
passenger = passenger_rs.DataFrame().set_index('EntryID')
passenger
# Out:
# Done.
#          OperatingID  AirportID  GeoID  ActivityID  TimeID  PublishedID  \
# EntryID
# 1                  1          1      1           1       1            1
# 2                  1          1      1           2       1            1
# 3                  1          1      1           3       1            1
# 4                  1          1      1           1       2            1
# 5                  1          1      1           2       2            1
# 6                  1          1      1           3       2            1
# 7                  1          1      1           1       3            1
# 8                  1          1      1           2       3            1
# 9                  1          1      1           3       3            1
# 10                 1          1      1           1       5            1
# 11                 1          1      1           2       5            1
# 12                 1          1      1           3       5            1
# 13                 1          1      1           1       6            1
# 14                 1          1      1           2       6            1
# 15                 1          1      1           3       6            1
# 16                 1          1      1           1       7            1
# 17                 1          1      1           2       7            1
# 18                 1          1      1           3       7            1
# 19                 1          1      1           1       8            1
# 20                 1          1      1           2       8            1
# 21                 1          1      1           3       8            1
# 22                 1          1      1           1       9            1
# 23                 1          1      1           2       9            1
# 24                 1          1      1           3       9            1
# 25                 1          1      1           1      10            1
# 26                 1          1      1           2      10            1
# 27                 1          1      1           3      10            1
# 28                 1          1      1           1      11            1
# 29                 1          1      1           2      11            1
# 30                 1          1      1           3      11            1
# ...              ...        ...    ...         ...     ...          ...
# 193786            54          9      1           1     145           47
# 193787            54          9      1           2     145           47
# 193788            54          9      2           2     145           47
# 193789            54          9      3           2     145           47
# 193790            54          9      4           2     145           47
# 193791            54          9      5           2     145           47
# 193792            54          9      6           2     145           47
# 193793            54          9      7           2     145           47
# 193794            54          9      8           2     145           47
# 193795            54          9      9           2     145           47
# 193796            54          9      1           1     146           47
# 193797            54          9      1           2     146           47
# 193798            54          9      2           2     146           47
# 193799            54          9      3           2     146           47
# 193800            54          9      4           2     146           47
# 193801            54          9      5           2     146           47
# 193802            54          9      6           2     146           47
# 193803            54          9      7           2     146           47
# 193804            54          9      8           2     146           47
# 193805            54          9      9           2     146           47
# 193806            54          9      1           1     147           47
# 193807            54          9      1           2     147           47
# 193808            54          9      2           2     147           47
# 193809            54          9      3           2     147           47
# 193810            54          9      4           2     147           47
# 193811            54          9      5           2     147           47
# 193812            54          9      6           2     147           47
# 193813            54          9      7           2     147           47
# 193814            54          9      8           2     147           47
# 193815            54          9      9           2     147           47
#
#          PassengerCount
# EntryID
# 1                 27271
# 2                 29131
# 3                  5415
# 4                 27472
# 5                 26535
# 6                  5712
# 7                 17341
# 8                 18541
# 9                  4412
# 10                17698
# 11                19983
# 12                 5754
# 13                16855
# 14                17376
# 15                 2911
# 16                15373
# 17                16790
# 18                 2402
# 19                13010
# 20                12226
# 21                 3316
# 22                 9180
# 23                10323
# 24                 3863
# 25                11583
# 26                11921
# 27                 3870
# 28                11920
# 29                11890
# 30                 2419
# ...                 ...
# 193786           236342
# 193787           231897
# 193788             5328
# 193789             5328
# 193790             5328
# 193791             5328
# 193792             5328
# 193793             5328
# 193794             5328
# 193795             5328
# 193796           236923
# 193797           233852
# 193798             3582
# 193799             3582
# 193800             3582
# 193801             3582
# 193802             3582
# 193803             3582
# 193804             3582
# 193805             3582
# 193806           218204
# 193807           223301
# 193808             1846
# 193809             1846
# 193810             1846
# 193811             1846
# 193812             1846
# 193813             1846
# 193814             1846
# 193815             1846
#
# [193815 rows x 7 columns]

# %%
# %%sql
# select terminal, sum(passengercount)
# from AIRPORTDIMENSION JOIN PASSENGERFACT ON (AIRPORTDIMENSION.AirportID = PASSENGERFACT.AirportID)
# group by terminal;
# Out:
# Done.
# [('International', 1805337136),
#  ('Other', 228),
#  ('Terminal 1', 407671524),
#  ('Terminal 2', 48724642),
#  ('Terminal 3', 559782518)]

# %%
airportterminal_rs = %sql None@airpassenger.db select ActivityType, sum(passengercount) from ACTIVITYDIMENSION JOIN PASSENGERFACT ON (ACTIVITYDIMENSION.ActivityID = PASSENGERFACT.ActivityID) group by ActivityType;
airportterminal = airportterminal_rs.DataFrame()
airportterminal
# Out:
# Done.
#      ActivityType  sum(passengercount)
# 0        Deplaned           1412383233
# 1        Enplaned           1399418473
# 2  Thru / Transit              9714342
